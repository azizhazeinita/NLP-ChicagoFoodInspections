# %% [markdown]
# ## Identify The Most Frequent Causes of Failed Food inspections in Chicago Using Natural Language Processing (NLP)

# %% [markdown]
# * **Project Goal:**
#
# This project aims to promote the food safety in Chicago by identifying the top 10 most frequent causes of failed food inspections in Chicago. It will also shows the top 10 least frequent causes as additional discovery of tendency and pattern that causes failed food inspections.
#
# * **Data Source:**
#
# Chicago Data Portal - Fodd inspections of restaurants and other food establishments in Chicago from January 1, 2010 to August 4, 2022. Inspections are performed by staff from the Chicago Department of Public Health’s Food Protection Program.
# https://data.cityofchicago.org/Health-Human-Services/Food-Inspections/4ijn-s7e5

# %%
import pandas as pd
import numpy as np
import re
import warnings
warnings.filterwarnings('ignore')

# %%
# Load The Data
df = pd.read_csv("/Users/azizhazeinita/Project/NLP/Food_Inspections.csv")
df.head()
# Out:
#    Inspection ID                DBA Name                AKA Name  License #  \
# 0        2561879                  SOLITA                  SOLITA  2857386.0
# 1        2559417               CHEZ JOEL               CHEZ JOEL    32359.0
# 2        2559999             ROJO GUSANO             ROJO GUSANO  1305286.0
# 3        2554552  HOST INTERNATIONAL B05    LA TAPENADE  (T1-B5)    34203.0
# 4        2553925  LITTLE HARVARD ACADEMY  LITTLE HARVARD ACADEMY  2215573.0
#
#            Facility Type           Risk               Address     City State  \
# 0             Restaurant   Risk 3 (Low)       431 N WELLS ST   CHICAGO    IL
# 1             Restaurant  Risk 1 (High)     1119 W TAYLOR ST   CHICAGO    IL
# 2             Restaurant  Risk 1 (High)  3830 W LAWRENCE AVE   CHICAGO    IL
# 3             Restaurant  Risk 1 (High)    11601 W TOUHY AVE   CHICAGO    IL
# 4  Daycare (2 - 6 Years)  Risk 1 (High)  2708 W PETERSON AVE   CHICAGO    IL
#
#        Zip Inspection Date Inspection Type          Results Violations  \
# 0  60654.0      08/09/2022         License             Pass        NaN
# 1  60607.0      06/15/2022  Non-Inspection         No Entry        NaN
# 2  60625.0      06/28/2022         Canvass  Out of Business        NaN
# 3  60666.0      04/20/2022         Canvass             Pass        NaN
# 4  60659.0      04/05/2022         Canvass  Out of Business        NaN
#
#     Latitude  Longitude                                  Location
# 0  41.890025 -87.633882   (-87.63388240330882, 41.89002468212031)
# 1  41.869332 -87.655107   (-87.65510678669794, 41.86933227916697)
# 2  41.968390 -87.724448  (-87.72444785924317, 41.968390431264375)
# 3  42.008536 -87.914428  (-87.91442843927047, 42.008536400868735)
# 4  41.990564 -87.697365   (-87.69736479750581, 41.99056361928264)

# %% [markdown]
# ### Selecting only the records corresponding to failed inspection ("Results" column)

# %%
# Filtering Dataframe Only With Value 'Fail' in Column 'Results'
df_fail = df[df.Results=='Fail']
df_fail.head()
# Out:
#      Inspection ID                 DBA Name                 AKA Name  \
# 20         2561623   LA CHOZA MEXICAN GRILL   LA CHOZA MEXICAN GRILL
# 50         2560320               iO Theater               iO Theater
# 109        2556045    REGGIE'S ON THE BEACH    REGGIE'S ON THE BEACH
# 135        2555232  HOT SEAFOOD MARKET INC.  HOT SEAFOOD MARKET INC.
# 141        2555124               PRIME FISH               PRIME FISH
#
#      License # Facility Type             Risk                    Address  \
# 20   1840862.0    Restaurant    Risk 1 (High)           7022 N CLARK ST
# 50   2850833.0    Restaurant     Risk 3 (Low)  1501-1519 N KINGSBURY ST
# 109  2840426.0    Restaurant     Risk 3 (Low)      6245 S LAKE SHORE DR
# 135  2840868.0    Restaurant  Risk 2 (Medium)  9454 S COTTAGE GROVE AVE
# 141  2463968.0    Restaurant    Risk 1 (High)         8022 S HALSTED ST
#
#         City State      Zip Inspection Date Inspection Type Results  \
# 20   CHICAGO    IL  60626.0      08/02/2022         Canvass    Fail
# 50   CHICAGO    IL  60642.0      07/06/2022         License    Fail
# 109  CHICAGO    IL  60637.0      05/19/2022         License    Fail
# 135  CHICAGO    IL  60619.0      05/04/2022         License    Fail
# 141  CHICAGO    IL  60620.0      05/02/2022         Canvass    Fail
#
#                                             Violations   Latitude  Longitude  \
# 20   9. NO BARE HAND CONTACT WITH RTE FOOD OR A PRE...  42.009698 -87.674274
# 50                                                 NaN  41.908306 -87.651800
# 109                                                NaN  41.780804 -87.574616
# 135  2. CITY OF CHICAGO FOOD SERVICE SANITATION CER...  41.722519 -87.604637
# 141  1. PERSON IN CHARGE PRESENT, DEMONSTRATES KNOW...  41.748104 -87.644115
#
#                                      Location
# 20   (-87.67427432484828, 42.009697980488845)
# 50    (-87.65179957092685, 41.90830578569197)
# 109  (-87.57461558340579, 41.780803899394144)
# 135   (-87.60463680899302, 41.72251869461573)
# 141   (-87.64411513161956, 41.74810405559482)

# %% [markdown]
# ### Cleaning the data to make sure that there are no NaNs in "Violations" column
# * "Violations" column lists the reasons for inspection failure

# %%
df_fail.Violations[20]
# Out:
# '9. NO BARE HAND CONTACT WITH RTE FOOD OR A PRE-APPROVED ALTERNATIVE PROCEDURE PROPERLY ALLOWED - Comments: OBSERVED THE EMPLOYEE SLICING FRESH TOMATOES AND ASSEMBLING READY-TO-EAT LETTUCE, ONION, AND TOMATOES FOR A SALAD WITH BARE HANDS. REVIEWED NO BARE HAND CONTACT WITH READY-TO-EAT FOODS. ALL FOODS DISCARDED. PRIORITY VIOLATION 7-38-010 CITATION ISSUED. | 15. FOOD SEPARATED AND PROTECTED - Comments: OBSERVED RAW CHICKEN ON THE COOK LINE CUTTING BOARD DIRECTLY NEXT TO FRESH READY-TO-EAT TOMATOES AND AVOCADO THAT WERE BEING SLICED AND PREPARED. ALSO OBSERVED WERE RAW EGGS STORED DIRECTLY ON TOP OF READY-TO-EAT TORTILLAS, ROASTED PEPPERS, AND RAW ONIONS IN THE TOP REFRIGERATION AREA OF THE COOKS LINE COOLER. ALL FOODS WERE REMOVED AND DISCARDED. PRIORITY VIOLATION 7-38-005 CITATION ISSUED. | 23. PROPER DATE MARKING AND DISPOSITION - Comments: OBSERVED ALL PREPARED TCS READY TO EAT FOODS THROUGHOUT ALL COOLERS NOT LABELED. NO EXPIRATION DATES OR PREP DATES. FOOD SUCH AS COOKED RICE, FLAN, COOKED MEATS AND BEANS. ALL FOODS DISCARDED. 100 LBS, $100. PRIORITY FOUNDATION VIOLATION 7-38-005 CITATION ISSUED. | 25. CONSUMER ADVISORY PROVIDED FOR RAW/UNDERCOOKED FOOD - Comments: NOTED ANIMAL ORIGIN UNDER COOKED FOODS SUCH AS OVER EASY EGGS ON THE MENU NOT DISCLOSED OR REMINDED FOR THE CONSUMER ADVISORY POSTED ON THE MENU. MUST DISCLOSE AND REMIND FOR SUCH ITEMS. PRIORITY FOUNDATION VIOLATION.  | 36. THERMOMETERS PROVIDED & ACCURATE - Comments: BROKEN INTERNAL THERMOMETER INSIDE THE COOKS LINE COOLER. MUST REPLACE. | 37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER - Comments: BULK DRIED PEPPER CONTAINERS MUST BE LABELED. | 41. WIPING CLOTHS: PROPERLY USED & STORED - Comments: OBSERVED SOILED WIPING CLOTHS ON PREP SURFACES THROUGHOUT. MUST STORE IN A CLEAN CONTAINER WITH A SANITIZING SOLUTION. | 45. SINGLE-USE/SINGLE-SERVICE ARTICLES: PROPERLY STORED & USED - Comments: ALL STORED ITEMS THROUGHOUT MUST BE ELEVATED FROM THE FLOORS INCLUDING CONSTRUCTION MATERIAL AT REAR STORAGE. | 47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: NOTED TORN RUBBER DOOR GASKETS REPAIRED WITH DUCT TAPE ON THE COOKS LINE COOLER AND TALL REACH-IN FREEZER. MUST REPLACE RUBBER GASKETS. | 47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: NOTED CRACKED/DAMAGED PLASTIC LIDS FOR THE PREPARED READY TO EAT FLAN. MUST REPLACE. | 47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: MUST NOT USE MILK CRATES OR RAW WOODEN BLOCKS AS A MEANS OF ELEVATION/SUPPORT FOR SHELVING. | 49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Comments: EXTREMELY DIRTY, FOOD ENCRUSTED SPICE CONTAINER ON THE COOKS LINE. MUST CLEAN AND MAINTAIN.-----NOTED PEELING DUCT TAPE BEING USED ON THE FOOD SHREDDER. MUST REPLACE FOOD SHREDDER. | 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: WATER DAMAGED CEILING TILES THROUGHOUT THE FRONT PREP AND REAR DISH AREA. MUST REPLACE.---- MISSING/DAMAGED WALL TILE AT THE UTILITY SERVICE SINK. MUST REPAIR/REPLACE. | 56. ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED - Comments: NOTED EMPLOYEES PERSONAL BELONGINGS BEING STORED IN THE FOOD PREP AREA. MUST PROVIDE DESIGNATED EMPLOYEE STORAGE FOR PERSONAL ITEMS AWAY FROM FOOD AND FOOD PREP. | 57. ALL FOOD EMPLOYEES HAVE FOOD HANDLER TRAINING - Comments: NO PROOF OF FOOD HANDLER TRAINING OR CERTIFICATE FOR THE EMPLOYEES. MUST PROVIDE. | 58. ALLERGEN TRAINING AS REQUIRED - Comments: NO PROOF OF ALLERGEN TRAINING OR CERTIFICATE FOR THE CITY OF CHICAGO CERTIFIED FOOD MANAGER MT CASTILLO. MUST PROVIDE. | 60. PREVIOUS CORE VIOLATION CORRECTED - Comments: PREVIOUS CORE VIOLATIONS FROM REPORT #2510080 ON 5-21-21 WERE NOT CORRECTED. #49- FOUND INTERIOR OF REACH IN COOLERS AND FREEZERS NOT CLEAN. MUST CLEAN AND SANITIZE.#55- FOUND FLOORS NOT CLEAN IN DISHWASHING AREAS. MUST CLEAN AND SANITIZE. PRIORITY FOUNDATION VIOLATION 7-42 090 CITATION ISSUED.'

# %% [markdown]
# * Those reasons in "Violations" column are separated by "|". Each reason consists of a regulation code, regulation description and comments describing how the regulation was violated.

# %%
# Drop Null Value in All Columns Based On The Null Value In Column 'Violations'
df_clean = df_fail.dropna(subset=['Violations'])
df_clean.head()
# Out:
#      Inspection ID                 DBA Name                 AKA Name  \
# 20         2561623   LA CHOZA MEXICAN GRILL   LA CHOZA MEXICAN GRILL
# 135        2555232  HOT SEAFOOD MARKET INC.  HOT SEAFOOD MARKET INC.
# 141        2555124               PRIME FISH               PRIME FISH
# 149        2554905       LAS BRISAS DEL MAR       LAS BRISAS DEL MAR
# 167        2554291                     MANA                     MANA
#
#      License #  Facility Type             Risk                    Address  \
# 20   1840862.0     Restaurant    Risk 1 (High)           7022 N CLARK ST
# 135  2840868.0     Restaurant  Risk 2 (Medium)  9454 S COTTAGE GROVE AVE
# 141  2463968.0     Restaurant    Risk 1 (High)         8022 S HALSTED ST
# 149    84625.0     Restaurant    Risk 1 (High)            3207 W 51ST ST
# 167  2712278.0  Grocery Store  Risk 2 (Medium)             434 E 71ST ST
#
#         City State      Zip Inspection Date Inspection Type Results  \
# 20   CHICAGO    IL  60626.0      08/02/2022         Canvass    Fail
# 135  CHICAGO    IL  60619.0      05/04/2022         License    Fail
# 141  CHICAGO    IL  60620.0      05/02/2022         Canvass    Fail
# 149  CHICAGO    IL  60632.0      04/27/2022         Canvass    Fail
# 167  CHICAGO    IL  60619.0      04/13/2022       Complaint    Fail
#
#                                             Violations   Latitude  Longitude  \
# 20   9. NO BARE HAND CONTACT WITH RTE FOOD OR A PRE...  42.009698 -87.674274
# 135  2. CITY OF CHICAGO FOOD SERVICE SANITATION CER...  41.722519 -87.604637
# 141  1. PERSON IN CHARGE PRESENT, DEMONSTRATES KNOW...  41.748104 -87.644115
# 149  3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL E...  41.800706 -87.704099
# 167  2. CITY OF CHICAGO FOOD SERVICE SANITATION CER...  41.765844 -87.613915
#
#                                      Location
# 20   (-87.67427432484828, 42.009697980488845)
# 135   (-87.60463680899302, 41.72251869461573)
# 141   (-87.64411513161956, 41.74810405559482)
# 149   (-87.70409936083796, 41.80070644396386)
# 167   (-87.61391496525177, 41.76584421474714)

# %% [markdown]
# ### Parsing "Violations" column to select <u>*only regulation descriptions*</u> using regular expression

# %%
# Showing Example of Violations Content From Random Index, This Case I Choose Index 20
df_clean.Violations[20]
# Out:
# '9. NO BARE HAND CONTACT WITH RTE FOOD OR A PRE-APPROVED ALTERNATIVE PROCEDURE PROPERLY ALLOWED - Comments: OBSERVED THE EMPLOYEE SLICING FRESH TOMATOES AND ASSEMBLING READY-TO-EAT LETTUCE, ONION, AND TOMATOES FOR A SALAD WITH BARE HANDS. REVIEWED NO BARE HAND CONTACT WITH READY-TO-EAT FOODS. ALL FOODS DISCARDED. PRIORITY VIOLATION 7-38-010 CITATION ISSUED. | 15. FOOD SEPARATED AND PROTECTED - Comments: OBSERVED RAW CHICKEN ON THE COOK LINE CUTTING BOARD DIRECTLY NEXT TO FRESH READY-TO-EAT TOMATOES AND AVOCADO THAT WERE BEING SLICED AND PREPARED. ALSO OBSERVED WERE RAW EGGS STORED DIRECTLY ON TOP OF READY-TO-EAT TORTILLAS, ROASTED PEPPERS, AND RAW ONIONS IN THE TOP REFRIGERATION AREA OF THE COOKS LINE COOLER. ALL FOODS WERE REMOVED AND DISCARDED. PRIORITY VIOLATION 7-38-005 CITATION ISSUED. | 23. PROPER DATE MARKING AND DISPOSITION - Comments: OBSERVED ALL PREPARED TCS READY TO EAT FOODS THROUGHOUT ALL COOLERS NOT LABELED. NO EXPIRATION DATES OR PREP DATES. FOOD SUCH AS COOKED RICE, FLAN, COOKED MEATS AND BEANS. ALL FOODS DISCARDED. 100 LBS, $100. PRIORITY FOUNDATION VIOLATION 7-38-005 CITATION ISSUED. | 25. CONSUMER ADVISORY PROVIDED FOR RAW/UNDERCOOKED FOOD - Comments: NOTED ANIMAL ORIGIN UNDER COOKED FOODS SUCH AS OVER EASY EGGS ON THE MENU NOT DISCLOSED OR REMINDED FOR THE CONSUMER ADVISORY POSTED ON THE MENU. MUST DISCLOSE AND REMIND FOR SUCH ITEMS. PRIORITY FOUNDATION VIOLATION.  | 36. THERMOMETERS PROVIDED & ACCURATE - Comments: BROKEN INTERNAL THERMOMETER INSIDE THE COOKS LINE COOLER. MUST REPLACE. | 37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER - Comments: BULK DRIED PEPPER CONTAINERS MUST BE LABELED. | 41. WIPING CLOTHS: PROPERLY USED & STORED - Comments: OBSERVED SOILED WIPING CLOTHS ON PREP SURFACES THROUGHOUT. MUST STORE IN A CLEAN CONTAINER WITH A SANITIZING SOLUTION. | 45. SINGLE-USE/SINGLE-SERVICE ARTICLES: PROPERLY STORED & USED - Comments: ALL STORED ITEMS THROUGHOUT MUST BE ELEVATED FROM THE FLOORS INCLUDING CONSTRUCTION MATERIAL AT REAR STORAGE. | 47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: NOTED TORN RUBBER DOOR GASKETS REPAIRED WITH DUCT TAPE ON THE COOKS LINE COOLER AND TALL REACH-IN FREEZER. MUST REPLACE RUBBER GASKETS. | 47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: NOTED CRACKED/DAMAGED PLASTIC LIDS FOR THE PREPARED READY TO EAT FLAN. MUST REPLACE. | 47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: MUST NOT USE MILK CRATES OR RAW WOODEN BLOCKS AS A MEANS OF ELEVATION/SUPPORT FOR SHELVING. | 49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Comments: EXTREMELY DIRTY, FOOD ENCRUSTED SPICE CONTAINER ON THE COOKS LINE. MUST CLEAN AND MAINTAIN.-----NOTED PEELING DUCT TAPE BEING USED ON THE FOOD SHREDDER. MUST REPLACE FOOD SHREDDER. | 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: WATER DAMAGED CEILING TILES THROUGHOUT THE FRONT PREP AND REAR DISH AREA. MUST REPLACE.---- MISSING/DAMAGED WALL TILE AT THE UTILITY SERVICE SINK. MUST REPAIR/REPLACE. | 56. ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED - Comments: NOTED EMPLOYEES PERSONAL BELONGINGS BEING STORED IN THE FOOD PREP AREA. MUST PROVIDE DESIGNATED EMPLOYEE STORAGE FOR PERSONAL ITEMS AWAY FROM FOOD AND FOOD PREP. | 57. ALL FOOD EMPLOYEES HAVE FOOD HANDLER TRAINING - Comments: NO PROOF OF FOOD HANDLER TRAINING OR CERTIFICATE FOR THE EMPLOYEES. MUST PROVIDE. | 58. ALLERGEN TRAINING AS REQUIRED - Comments: NO PROOF OF ALLERGEN TRAINING OR CERTIFICATE FOR THE CITY OF CHICAGO CERTIFIED FOOD MANAGER MT CASTILLO. MUST PROVIDE. | 60. PREVIOUS CORE VIOLATION CORRECTED - Comments: PREVIOUS CORE VIOLATIONS FROM REPORT #2510080 ON 5-21-21 WERE NOT CORRECTED. #49- FOUND INTERIOR OF REACH IN COOLERS AND FREEZERS NOT CLEAN. MUST CLEAN AND SANITIZE.#55- FOUND FLOORS NOT CLEAN IN DISHWASHING AREAS. MUST CLEAN AND SANITIZE. PRIORITY FOUNDATION VIOLATION 7-42 090 CITATION ISSUED.'

# %%
# Remove Comments, Leave only  regulation code and description
a = df_clean.Violations.apply(lambda x: re.sub(r'\s?\-\s+Comments.*?\|','',x))
a[20]
# Out:
# '9. NO BARE HAND CONTACT WITH RTE FOOD OR A PRE-APPROVED ALTERNATIVE PROCEDURE PROPERLY ALLOWED 15. FOOD SEPARATED AND PROTECTED 23. PROPER DATE MARKING AND DISPOSITION 25. CONSUMER ADVISORY PROVIDED FOR RAW/UNDERCOOKED FOOD 36. THERMOMETERS PROVIDED & ACCURATE 37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER 41. WIPING CLOTHS: PROPERLY USED & STORED 45. SINGLE-USE/SINGLE-SERVICE ARTICLES: PROPERLY STORED & USED 47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED 47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED 47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED 49. NON-FOOD/FOOD CONTACT SURFACES CLEAN 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN 56. ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED 57. ALL FOOD EMPLOYEES HAVE FOOD HANDLER TRAINING 58. ALLERGEN TRAINING AS REQUIRED 60. PREVIOUS CORE VIOLATION CORRECTED - Comments: PREVIOUS CORE VIOLATIONS FROM REPORT #2510080 ON 5-21-21 WERE NOT CORRECTED. #49- FOUND INTERIOR OF REACH IN COOLERS AND FREEZERS NOT CLEAN. MUST CLEAN AND SANITIZE.#55- FOUND FLOORS NOT CLEAN IN DISHWASHING AREAS. MUST CLEAN AND SANITIZE. PRIORITY FOUNDATION VIOLATION 7-42 090 CITATION ISSUED.'

# %%
# Remove Comment Residue in The Last Paragraph
b = a.apply(lambda x: re.sub(r'\s?\-\s+Comments.*','',x))
b[20]
# Out:
# '9. NO BARE HAND CONTACT WITH RTE FOOD OR A PRE-APPROVED ALTERNATIVE PROCEDURE PROPERLY ALLOWED 15. FOOD SEPARATED AND PROTECTED 23. PROPER DATE MARKING AND DISPOSITION 25. CONSUMER ADVISORY PROVIDED FOR RAW/UNDERCOOKED FOOD 36. THERMOMETERS PROVIDED & ACCURATE 37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER 41. WIPING CLOTHS: PROPERLY USED & STORED 45. SINGLE-USE/SINGLE-SERVICE ARTICLES: PROPERLY STORED & USED 47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED 47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED 47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED 49. NON-FOOD/FOOD CONTACT SURFACES CLEAN 55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN 56. ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED 57. ALL FOOD EMPLOYEES HAVE FOOD HANDLER TRAINING 58. ALLERGEN TRAINING AS REQUIRED 60. PREVIOUS CORE VIOLATION CORRECTED'

# %%
# Remove Regulation Code
c = b.apply(lambda x: re.sub(r'\s\d+','', str(x)))
c[20]
# Out:
# '9. NO BARE HAND CONTACT WITH RTE FOOD OR A PRE-APPROVED ALTERNATIVE PROCEDURE PROPERLY ALLOWED. FOOD SEPARATED AND PROTECTED. PROPER DATE MARKING AND DISPOSITION. CONSUMER ADVISORY PROVIDED FOR RAW/UNDERCOOKED FOOD. THERMOMETERS PROVIDED & ACCURATE. FOOD PROPERLY LABELED; ORIGINAL CONTAINER. WIPING CLOTHS: PROPERLY USED & STORED. SINGLE-USE/SINGLE-SERVICE ARTICLES: PROPERLY STORED & USED. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED. NON-FOOD/FOOD CONTACT SURFACES CLEAN. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN. ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED. ALL FOOD EMPLOYEES HAVE FOOD HANDLER TRAINING. ALLERGEN TRAINING AS REQUIRED. PREVIOUS CORE VIOLATION CORRECTED'

# %%
# Remove Regulation Code Residue In The Beginning of Paragraphs
d = c.apply(lambda x: re.sub(r'^\d+\W+ | ^\d?\.', '', x))
d[20]
# Out:
# 'NO BARE HAND CONTACT WITH RTE FOOD OR A PRE-APPROVED ALTERNATIVE PROCEDURE PROPERLY ALLOWED. FOOD SEPARATED AND PROTECTED. PROPER DATE MARKING AND DISPOSITION. CONSUMER ADVISORY PROVIDED FOR RAW/UNDERCOOKED FOOD. THERMOMETERS PROVIDED & ACCURATE. FOOD PROPERLY LABELED; ORIGINAL CONTAINER. WIPING CLOTHS: PROPERLY USED & STORED. SINGLE-USE/SINGLE-SERVICE ARTICLES: PROPERLY STORED & USED. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED. NON-FOOD/FOOD CONTACT SURFACES CLEAN. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN. ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED. ALL FOOD EMPLOYEES HAVE FOOD HANDLER TRAINING. ALLERGEN TRAINING AS REQUIRED. PREVIOUS CORE VIOLATION CORRECTED'

# %%
# These codes below are to make sure that other rows besides row 20 are already clened well

# Make Sure To Remove All '|'
e = d.apply(lambda x: re.sub(r'([\|])','', str(x)))

# Make Sure To Remove All Space At The End of Sentences
f = e.apply(lambda x: re.sub('([\w]) ([.])', r'\1\2', str(x)))

# Make Sure To Remove All Space At The Beginning of Sentences
g = f.apply(lambda x: re.sub(r'\^s','', str(x)))

# Remove Space After Dots, So It Can Be Easy To Split (Based On Dots)
desc = g.apply(lambda x: re.sub('([.]) ([\w])', r'\1\2', str(x)))

# %%
# Store Description-Only Into DataFrame
df_clean['Description'] = desc
df_clean.head()
# Out:
#      Inspection ID                 DBA Name                 AKA Name  \
# 20         2561623   LA CHOZA MEXICAN GRILL   LA CHOZA MEXICAN GRILL
# 135        2555232  HOT SEAFOOD MARKET INC.  HOT SEAFOOD MARKET INC.
# 141        2555124               PRIME FISH               PRIME FISH
# 149        2554905       LAS BRISAS DEL MAR       LAS BRISAS DEL MAR
# 167        2554291                     MANA                     MANA
#
#      License #  Facility Type             Risk                    Address  \
# 20   1840862.0     Restaurant    Risk 1 (High)           7022 N CLARK ST
# 135  2840868.0     Restaurant  Risk 2 (Medium)  9454 S COTTAGE GROVE AVE
# 141  2463968.0     Restaurant    Risk 1 (High)         8022 S HALSTED ST
# 149    84625.0     Restaurant    Risk 1 (High)            3207 W 51ST ST
# 167  2712278.0  Grocery Store  Risk 2 (Medium)             434 E 71ST ST
#
#         City State      Zip Inspection Date Inspection Type Results  \
# 20   CHICAGO    IL  60626.0      08/02/2022         Canvass    Fail
# 135  CHICAGO    IL  60619.0      05/04/2022         License    Fail
# 141  CHICAGO    IL  60620.0      05/02/2022         Canvass    Fail
# 149  CHICAGO    IL  60632.0      04/27/2022         Canvass    Fail
# 167  CHICAGO    IL  60619.0      04/13/2022       Complaint    Fail
#
#                                             Violations   Latitude  Longitude  \
# 20   9. NO BARE HAND CONTACT WITH RTE FOOD OR A PRE...  42.009698 -87.674274
# 135  2. CITY OF CHICAGO FOOD SERVICE SANITATION CER...  41.722519 -87.604637
# 141  1. PERSON IN CHARGE PRESENT, DEMONSTRATES KNOW...  41.748104 -87.644115
# 149  3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL E...  41.800706 -87.704099
# 167  2. CITY OF CHICAGO FOOD SERVICE SANITATION CER...  41.765844 -87.613915
#
#                                      Location  \
# 20   (-87.67427432484828, 42.009697980488845)
# 135   (-87.60463680899302, 41.72251869461573)
# 141   (-87.64411513161956, 41.74810405559482)
# 149   (-87.70409936083796, 41.80070644396386)
# 167   (-87.61391496525177, 41.76584421474714)
#
#                                            Description
# 20   NO BARE HAND CONTACT WITH RTE FOOD OR A PRE-AP...
# 135  CITY OF CHICAGO FOOD SERVICE SANITATION CERTIF...
# 141  PERSON IN CHARGE PRESENT, DEMONSTRATES KNOWLED...
# 149  MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL EMPL...
# 167  CITY OF CHICAGO FOOD SERVICE SANITATION CERTIF...

# %% [markdown]
# ### Counting how many times each regulation description occurred in the table

# %%
from collections import Counter

# %%
# Just to Check The Initial Paragraph
df_clean['Description'].iloc[0]
# Out:
# 'NO BARE HAND CONTACT WITH RTE FOOD OR A PRE-APPROVED ALTERNATIVE PROCEDURE PROPERLY ALLOWED.FOOD SEPARATED AND PROTECTED.PROPER DATE MARKING AND DISPOSITION.CONSUMER ADVISORY PROVIDED FOR RAW/UNDERCOOKED FOOD.THERMOMETERS PROVIDED & ACCURATE.FOOD PROPERLY LABELED; ORIGINAL CONTAINER.WIPING CLOTHS: PROPERLY USED & STORED.SINGLE-USE/SINGLE-SERVICE ARTICLES: PROPERLY STORED & USED.FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED.FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED.FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED.NON-FOOD/FOOD CONTACT SURFACES CLEAN.PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN.ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED.ALL FOOD EMPLOYEES HAVE FOOD HANDLER TRAINING.ALLERGEN TRAINING AS REQUIRED.PREVIOUS CORE VIOLATION CORRECTED'

# %%
# Split The Description in Each Row
split = df_clean['Description'].str.split(pat='.')
split[20]
# Out:
# ['NO BARE HAND CONTACT WITH RTE FOOD OR A PRE-APPROVED ALTERNATIVE PROCEDURE PROPERLY ALLOWED',
#  'FOOD SEPARATED AND PROTECTED',
#  'PROPER DATE MARKING AND DISPOSITION',
#  'CONSUMER ADVISORY PROVIDED FOR RAW/UNDERCOOKED FOOD',
#  'THERMOMETERS PROVIDED & ACCURATE',
#  'FOOD PROPERLY LABELED; ORIGINAL CONTAINER',
#  'WIPING CLOTHS: PROPERLY USED & STORED',
#  'SINGLE-USE/SINGLE-SERVICE ARTICLES: PROPERLY STORED & USED',
#  'FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED',
#  'FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED',
#  'FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED',
#  'NON-FOOD/FOOD CONTACT SURFACES CLEAN',
#  'PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN',
#  'ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED',
#  'ALL FOOD EMPLOYEES HAVE FOOD HANDLER TRAINING',
#  'ALLERGEN TRAINING AS REQUIRED',
#  'PREVIOUS CORE VIOLATION CORRECTED']

# %%
# Store Splitted Description Into Current DataFrame
df_split = pd.DataFrame(split)

# Count Each Sentence
count = Counter(df_split['Description'].explode())
count
# Out:
# Counter({'NO BARE HAND CONTACT WITH RTE FOOD OR A PRE-APPROVED ALTERNATIVE PROCEDURE PROPERLY ALLOWED': 155,
#          'FOOD SEPARATED AND PROTECTED': 174,
#          'PROPER DATE MARKING AND DISPOSITION': 1734,
#          'CONSUMER ADVISORY PROVIDED FOR RAW/UNDERCOOKED FOOD': 1824,
#          'THERMOMETERS PROVIDED & ACCURATE': 2550,
#          'FOOD PROPERLY LABELED; ORIGINAL CONTAINER': 2337,
#          'WIPING CLOTHS: PROPERLY USED & STORED': 1283,
#          'SINGLE-USE/SINGLE-SERVICE ARTICLES: PROPERLY STORED & USED': 523,
#          'FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED': 5989,
#          'NON-FOOD/FOOD CONTACT SURFACES CLEAN': 4904,
#          'PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN': 13761,
#          'ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED': 4161,
#          'ALL FOOD EMPLOYEES HAVE FOOD HANDLER TRAINING': 2869,
#          'ALLERGEN TRAINING AS REQUIRED': 3187,
#          'PREVIOUS CORE VIOLATION CORRECTED': 2193,
#          'CITY OF CHICAGO FOOD SERVICE SANITATION CERTIFICATE': 2076,
#          'MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL EMPLOYEE; KNOWLEDGE, RESPONSIBILITIES AND REPORTING': 4995,
#          'ADEQUATE HANDWASHING SINKS PROPERLY SUPPLIED AND ACCESSIBLE': 7021,
#          'PROPER COOLING METHODS USED; ADEQUATE EQUIPMENT FOR TEMPERATURE CONTROL': 1217,
#          'INSECTS, RODENTS, & ANIMALS NOT PRESENT': 7346,
#          'PLUMBING INSTALLED; PROPER BACKFLOW DEVICES': 5046,
#          'GARBAGE & REFUSE PROPERLY DISPOSED; FACILITIES MAINTAINED': 1682,
#          'COMPLIANCE WITH CLEAN INDOOR AIR ORDINANCE': 68,
#          'PERSON IN CHARGE PRESENT, DEMONSTRATES KNOWLEDGE, AND PERFORMS DUTIES': 1115,
#          'PROPER COLD HOLDING TEMPERATURES': 1382,
#          'WAREWASHING FACILITIES: INSTALLED, MAINTAINED & USED; TEST STRIPS': 3101,
#          'REQUIRED RECORDS AVAILABLE: SHELLSTOCK TAGS, PARASITE DESTRUCTION': 178,
#          'GLOVES USED PROPERLY': 60,
#          'TOILET FACILITIES: PROPERLY CONSTRUCTED, SUPPLIED, & CLEANED': 3104,
#          'FOOD-CONTACT SURFACES: CLEANED & SANITIZED': 1823,
#          'IN-USE UTENSILS: PROPERLY STORED': 545,
#          'UTENSILS, EQUIPMENT & LINENS: PROPERLY STORED, DRIED, & HANDLED': 649,
#          'PROPER HOT HOLDING TEMPERATURES': 348,
#          'TOXIC SUBSTANCES PROPERLY IDENTIFIED, STORED, & USED': 110,
#          'CONTAMINATION PREVENTED DURING FOOD PREPARATION, STORAGE & DISPLAY': 1938,
#          'PROCEDURES FOR RESPONDING TO VOMITING AND DIARRHEAL EVENTS': 5296,
#          'SEWAGE & WASTE WATER PROPERLY DISPOSED': 674,
#          'COMPLIANCE WITH VARIANCE/SPECIALIZED PROCESS/HACCP': 167,
#          'MISCELLANEOUS / PUBLIC HEALTH ORDERS': 376,
#          'SUMMARY REPORT DISPLAYED AND VISIBLE TO THE PUBLIC': 480,
#          'HANDS CLEAN & PROPERLY WASHED': 208,
#          'FOOD OBTAINED FROM APPROVED SOURCE': 48,
#          'VARIANCE OBTAINED FOR SPECIALIZED PROCESSING METHODS': 102,
#          'HOT & COLD WATER AVAILABLE; ADEQUATE PRESSURE': 626,
#          'PERSONAL CLEANLINESS': 746,
#          'PREVIOUS PRIORITY FOUNDATION VIOLATION CORRECTED': 737,
#          'TIME AS A PUBLIC HEALTH CONTROL; PROCEDURES & RECORDS': 15,
#          'PROPER COOLING TIME AND TEMPERATURE': 24,
#          'APPROVED THAWING METHODS USED': 159,
#          'FOOD IN GOOD CONDITION, SAFE, & UNADULTERATED': 74,
#          'FACILITIES TO MAINTAIN PROPER TEMPERATURE': 3549,
#          'POTENTIALLY HAZARDOUS FOOD MEETS TEMPERATURE REQUIREMENT DURING STORAGE, PREPARATION DISPLAY AND SERVICE': 3652,
#          'NO EVIDENCE OF RODENT OR INSECT OUTER OPENINGS PROTECTED/RODENT PROOFED, A WRITTEN LOG SHALL BE MAINTAINED AVAILABLE TO THE INSPECTORS': 16432,
#          'FOOD IN ORIGINAL CONTAINER, PROPERLY LABELED: CUSTOMER ADVISORY POSTED AS NEEDED': 4216,
#          'CLEAN MULTI-USE UTENSILS AND SINGLE SERVICE ARTICLES PROPERLY STORED: NO REUSE OF SINGLE SERVICE ARTICLES': 2722,
#          'FOOD AND NON-FOOD CONTACT SURFACES PROPERLY DESIGNED, CONSTRUCTED AND MAINTAINED': 15019,
#          'FOOD AND NON-FOOD CONTACT EQUIPMENT UTENSILS CLEAN, FREE OF ABRASIVE DETERGENTS': 16445,
#          'FLOORS: CONSTRUCTED PER CODE, CLEANED, GOOD REPAIR, COVING INSTALLED, DUST-LESS CLEANING METHODS USED': 19371,
#          'WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTRUCTED PER CODE: GOOD REPAIR, SURFACES CLEAN AND DUST-LESS CLEANING METHODS': 18257,
#          'VENTILATION: ROOMS AND EQUIPMENT VENTED AS REQUIRED: PLUMBING: INSTALLED AND MAINTAINED': 15529,
#          'FOOD (ICE) DISPENSING UTENSILS, WASH CLOTHS PROPERLY STORED': 2241,
#          'PREVIOUS SERIOUS VIOLATION CORRECTED,-42-090': 892,
#          'OUTSIDE GARBAGE WASTE GREASE AND STORAGE AREA; CLEAN, RODENT PROOF, ALL CONTAINERS COVERED': 3887,
#          'PREVIOUS MINOR VIOLATION(S) CORRECTED-42-090': 5548,
#          'PREMISES MAINTAINED FREE OF LITTER, UNNECESSARY ARTICLES, CLEANING  EQUIPMENT PROPERLY STORED': 10667,
#          'FOOD PROTECTED DURING STORAGE, PREPARATION, DISPLAY, SERVICE AND TRANSPORTATION': 3742,
#          ' * CERTIFIED FOOD MANAGER ON SITE WHEN POTENTIALLY HAZARDOUS FOODS ARE  PREPARED AND SERVED': 3450,
#          'DISH MACHINES: PROVIDED WITH ACCURATE THERMOMETERS, CHEMICAL TEST KITS AND SUITABLE GAUGE COCK': 1039,
#          'LIGHTING: REQUIRED MINIMUM FOOT-CANDLES OF LIGHT PROVIDED, FIXTURES SHIELDED': 7736,
#          'FOOD HANDLER REQUIREMENTS MET': 1920,
#          'REFRIGERATION AND METAL STEM THERMOMETERS PROVIDED AND CONSPICUOUS': 4627,
#          'HANDS WASHED AND CLEANED, GOOD HYGIENIC PRACTICES; NO BARE HAND CONTACT WITH READY-TO-EAT FOODS': 833,
#          '': 833,
#          'APPROPRIATE METHOD OF HANDLING OF FOOD (ICE) HAIR RESTRAINTS AND CLEAN APPAREL WORN': 1679,
#          'ADEQUATE NUMBER, CONVENIENT, ACCESSIBLE, PROPERLY DESIGNED AND INSTALLED': 1331,
#          'ADEQUATE NUMBER, CONVENIENT, ACCESSIBLE, DESIGNED, AND MAINTAINED': 2849,
#          'DISH WASHING FACILITIES: PROPERLY DESIGNED, CONSTRUCTED, MAINTAINED, INSTALLED, LOCATED AND OPERATED': 2993,
#          'HAND WASHING FACILITIES: WITH SOAP AND SANITARY HAND DRYING DEVICES, CONVENIENT AND ACCESSIBLE TO FOOD PREP AREA': 1904,
#          'SOURCE SOUND CONDITION, NO SPOILAGE, FOODS PROPERLY LABELED, SHELLFISH TAGS IN PLACE': 364,
#          'NO EVIDENCE OF RODENT OR INSECT INFESTATION, NO BIRDS, TURTLES OR OTHER ANIMALS': 601,
#          ' * INSPECTION REPORT SUMMARY DISPLAYED AND VISIBLE TO ALL CUSTOMERS': 581,
#          'WASH AND RINSE WATER: CLEAN AND PROPER TEMPERATURE': 88,
#          'TOILET ROOM DOORS SELF CLOSING: DRESSING ROOMS WITH LOCKERS PROVIDED: COMPLETE SEPARATION FROM LIVING/SLEEPING QUARTERS': 2517,
#          'SANITIZING RINSE FOR EQUIPMENT AND UTENSILS:  CLEAN, PROPER TEMPERATURE, CONCENTRATION, EXPOSURE TIME': 1347,
#          'POTENTIALLY HAZARDOUS FOOD PROPERLY THAWED': 64,
#          'SEWAGE AND WASTE WATER DISPOSAL, NO BACK SIPHONAGE, CROSS  CONNECTION AND/OR BACK FLOW': 694,
#          'NO SMOKING REGULATIONS': 403,
#          'CERTIFIED FOOD MANAGER ON SITE WHEN POTENTIALLY HAZARDOUS FOODS ARE  PREPARED AND SERVED': 609,
#          'LINEN: CLEAN AND SOILED PROPERLY STORED': 229,
#          'WATER SOURCE: SAFE, HOT & COLD UNDER CITY PRESSURE': 1343,
#          'TOXIC ITEMS PROPERLY STORED, LABELED AND USED': 117,
#          'TOILET ROOMS ENCLOSED CLEAN, PROVIDED WITH HAND CLEANSER, SANITARY HAND DRYING DEVICES AND PROPER WASTE RECEPTACLES': 289,
#          'SOURCE OF CROSS CONTAMINATION CONTROLLED I': 249,
#          'E': 249,
#          'CUTTING BOARDS, FOOD  HANDLERS, UTENSILS, ETC': 249,
#          'ONLY AUTHORIZED PERSONNEL IN THE FOOD-PREP AREA': 131,
#          'INSIDE CONTAINERS OR RECEPTACLES: ADEQUATE NUMBER, PROPERLY COVERED AND INSECT/RODENT PROOF': 97,
#          'PROPER EATING, TASTING, DRINKING, OR TOBACCO USE': 77,
#          'PROPER REHEATING PROCEDURES FOR HOT HOLDING': 19,
#          'PROPER COOKING TIME & TEMPERATURES': 4,
#          'FOOD RECEIVED AT PROPER TEMPERATURE': 9,
#          'PROPER DISPOSITION OF RETURNED, PREVIOUSLY SERVED, RECONDITIONED & UNSAFE FOOD': 6,
#          'REMOVAL OF SUSPENSION SIGN': 7,
#          'WATER & ICE FROM APPROVED SOURCE': 6,
#          'NO DISCHARGE FROM EYES, NOSE, AND MOUTH': 3,
#          'PROPER USE OF RESTRICTION AND EXCLUSION': 3,
#          'PLANT FOOD PROPERLY COOKED FOR HOT HOLDING': 1,
#          'WASHING FRUITS & VEGETABLES': 1,
#          'UNWRAPPED AND POTENTIALLY HAZARDOUS FOOD NOT RE-SERVED': 1,
#          'PASTEURIZED EGGS USED WHERE REQUIRED': 1,
#          'DISHES AND UTENSILS FLUSHED, SCRAPED, SOAKED': 5,
#          'INSPECTION REPORT SUMMARY DISPLAYED AND VISIBLE TO ALL CUSTOMERS': 38,
#          'PERSONNEL WITH INFECTIONS RESTRICTED: NO OPEN SORES, WOUNDS, ETC': 9})

# %% [markdown]
# ### Showing top 10 MOST and LEAST frequent regulation descriptions

# %% [markdown]
# ### TOP 10 Most Frequent

# %%
# Showing top 10 most frequent regulation descriptions
top_ten = pd.DataFrame(count.most_common(10))
top_ten = top_ten.rename(columns={0: "Top 10 # Regulation Descriptions", 1: "Count"})
top_ten['Percentage'] = (top_ten['Count']/df_split.count()[0])*100
pd.set_option('display.max_colwidth', 4000)
top_ten
# Out:
#                                                                                                          Top 10 # Regulation Descriptions  \
# 0                                   FLOORS: CONSTRUCTED PER CODE, CLEANED, GOOD REPAIR, COVING INSTALLED, DUST-LESS CLEANING METHODS USED
# 1                    WALLS, CEILINGS, ATTACHED EQUIPMENT CONSTRUCTED PER CODE: GOOD REPAIR, SURFACES CLEAN AND DUST-LESS CLEANING METHODS
# 2                                                         FOOD AND NON-FOOD CONTACT EQUIPMENT UTENSILS CLEAN, FREE OF ABRASIVE DETERGENTS
# 3  NO EVIDENCE OF RODENT OR INSECT OUTER OPENINGS PROTECTED/RODENT PROOFED, A WRITTEN LOG SHALL BE MAINTAINED AVAILABLE TO THE INSPECTORS
# 4                                                 VENTILATION: ROOMS AND EQUIPMENT VENTED AS REQUIRED: PLUMBING: INSTALLED AND MAINTAINED
# 5                                                        FOOD AND NON-FOOD CONTACT SURFACES PROPERLY DESIGNED, CONSTRUCTED AND MAINTAINED
# 6                                                                                       PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN
# 7                                           PREMISES MAINTAINED FREE OF LITTER, UNNECESSARY ARTICLES, CLEANING  EQUIPMENT PROPERLY STORED
# 8                                                            LIGHTING: REQUIRED MINIMUM FOOT-CANDLES OF LIGHT PROVIDED, FIXTURES SHIELDED
# 9                                                                                                 INSECTS, RODENTS, & ANIMALS NOT PRESENT
#
#    Count  Percentage
# 0  19371   44.889115
# 1  18257   42.307603
# 2  16445   38.108590
# 3  16432   38.078465
# 4  15529   35.985911
# 5  15019   34.804069
# 6  13761   31.888861
# 7  10667   24.719023
# 8   7736   17.926911
# 9   7346   17.023150

# %% [markdown]
# ### TOP 10 Least Frequent

# %%
#Showing last 10 most frequent regulation descriptions
last_ten = pd.DataFrame(count.most_common()[:-1-10:-1])
last_ten = last_ten.rename(columns={0: "Last 10 # Regulation Descriptions", 1: "Count"})
last_ten['Percentage'] = (last_ten['Count']/df_split.count()[0])*100
pd.set_option('display.max_colwidth', 4000)
last_ten
# Out:
#                                                 Last 10 # Regulation Descriptions  \
# 0                                            PASTEURIZED EGGS USED WHERE REQUIRED
# 1                          UNWRAPPED AND POTENTIALLY HAZARDOUS FOOD NOT RE-SERVED
# 2                                                     WASHING FRUITS & VEGETABLES
# 3                                      PLANT FOOD PROPERLY COOKED FOR HOT HOLDING
# 4                                         PROPER USE OF RESTRICTION AND EXCLUSION
# 5                                         NO DISCHARGE FROM EYES, NOSE, AND MOUTH
# 6                                              PROPER COOKING TIME & TEMPERATURES
# 7                                    DISHES AND UTENSILS FLUSHED, SCRAPED, SOAKED
# 8                                                WATER & ICE FROM APPROVED SOURCE
# 9  PROPER DISPOSITION OF RETURNED, PREVIOUSLY SERVED, RECONDITIONED & UNSAFE FOOD
#
#    Count  Percentage
# 0      1    0.002317
# 1      1    0.002317
# 2      1    0.002317
# 3      1    0.002317
# 4      3    0.006952
# 5      3    0.006952
# 6      4    0.009269
# 7      5    0.011587
# 8      6    0.013904
# 9      6    0.013904

# %% [markdown]
# ### Summary
#
# * The majority factor that causes food inspection rejection is the **quality of floor** in the restaurant or food establishment, it's **almost 45%** cause of failed inspection
# * **9 of top 10 frequent** causes are related to **facilites and equipments**, while the rest is about harmful animals
# * **Most of top 10 least** are about **process** of preparing or cooking food
